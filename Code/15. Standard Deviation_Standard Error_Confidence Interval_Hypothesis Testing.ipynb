# %% [markdown]
# ### Population, Sample, Sample Distribution, Sampling Distribution

# %% [markdown]
#     Population:
#     -----------
#         The whole true data which we want to study or learn the ML algorithm. It is almost always impossible and difficult to collect all the data points from the population due to time, financial, or technical limitations.
#
#     Sample:
#     --------
#         Sample is the random data which we extract from the population. Sample << Population. We collect the sample data and we make inferences about the population data using this sample data
#
#      Sample Distribution:
#      --------------------
#          The "distribution of the data in a sample" which is randomly taken from a population is called sample distribution. The distribution will have different statistics which are mean, standard deviation, variance, proportion etc.,
#
#          Eg: For example, we ask 100 random people in Los Angeles what their incomes are. The sample distribution describes the ACTUAL income distribution in these 100 people.
#
#      Sampling Distribution:
#      ---------------------
#          The "distribution of the sample statistics" (sample mean, sample variance, sample standard deviation, and sample proportion) over many samples drawn from the same population(i.e., repeated sampling) is called Sampling distribution.
#
#          Eg: For example, we ask 100 random people in Los Angeles what their incomes are. Then compute the average income. We repeat this 1000 times, then we have 1000 different average incomes. The distribution of these 1000 average incomes is called the sampling distribution.
#
#          Note: In repeated samples, the same subjects are tested under different conditions. For example, the weight of 10 adults is measured. After that, they undergo an exercise program and the weight of the same 10 adults is measured again
#
#       Statistical inference:
#       ----------------------
#           It is the process of using a random sample from a population to infer the properties of a whole population. To put simply, statistical inference is the process through which inferences(conclusions/results) about a population are made based on certain statistics calculated from a sample of data drawn.
#           There are three common forms of Statistical Inference. Each one has a different way of using sample data to make conclusions about the population. They are: Point Estimation, Interval Estimation, Hypothesis Testing
#
#             1. Point Estimation: For Point Estimate, we infer an unknown population parameter using a single value based on the sample data.For eg, we can use the average household income (i.e., sample mean) from the sample data(100 households in Los Angeles)  to infer the average house income in Los Angeles (i.e., population mean).Beware that point estimation is subject to uncertainty because when we do the point estimate from another sample set(of sample size), it will most likely varies from previous sample statistic. To put simply,  Point estimation doesn’t give us any idea as to how good the estimation is.
#
#             2. Interval Estimation: For Interval Estimation, we use an interval of values (aka Confidence Interval) to estimate an unknown population parameter, and state how confident(probability or confidence level) we are that this interval would include the true population parameter.
#
#             3. Hypothesis Testing: Unlike point estimate and interval estimate which are used to infer population parameters based on sample data, the purpose of hypothesis testing is to evaluate the "strength of evidence from the sample data" for making conclusions about the population.

# %% [markdown]
# ### Standard Deviation

# %% [markdown]
#     The standard deviation measures the amount of variability/dispersion (aka, the spread) of the individual data points around the mean in a given dataset.
#
#     In other words, it is the "statistic which tells us, on average, how far each data point is away from the mean".
#
#     Standard deviation can be calculated from sample or also from population.But since, we always dont have the full popluation, we always use sample standard deviation to infer population standard deviation
#
#     True population standard deviation:
#     ------------------------------------
# ![population_standard_deviation.svg](attachment:population_standard_deviation.svg)
#
#     where σ is the sd of the population, μ is the population mean, xi is the data item, N is the size of the population

# %% [markdown]
#     Sample standard deviation:
#     ---------------------------
# ![sample_standard_deviation.svg](attachment:sample_standard_deviation.svg)
#
#     where s = sample standard deviation, x̄ = sample mean, N = no. of observations in the sample, xi is the data item
#
#     -------------------------------------------------------------------
#     Why we use N-1 in the denominator for sample standard deviation?
#     -------------------------------------------------------------------
#         You will notice that we are using the sample mean (x̄) instead of the population mean (μ) for the sample standard deviation because we don't know anything about the population mean. x̄ is a reasonable estimate for μ. Therefore, any value X in the sample dataset would be closer to x̄ than to μ. The numerator in the sample standard deviation would get artificially smaller than it is supposed to be. As a result, the sample standard deviation would be underestimated.
#         To correct this bias in the sample standard deviation, we would use "n-1" instead of "n" (aka, Bessel’s correction) for sample standard deviation. Using n-1 would make the sample standard deviation larger than otherwise using n. Therefore, we have a less biased estimate of the population standard deviation, giving us a conservative estimate of variability.

# %% [markdown]
# ### Standard Error

# %% [markdown]
#     Standard error is the "statistic that measures the variability of a statistic"(mean,sd,variance..) in the "sampling distribution".
#
#     In other words, Standard error of the mean (or simply Standard Error) measures how far the sample mean of the data is likely to be from the true population mean.
#
#     Standard Error is calculated for several statistics like Mean, Standard Deviation and so on.
#
# ![standard_error.svg](attachment:standard_error.svg)
#
#     where SE is the standard error of the population, n is the no of observations in the population, σ is the standard deviation of the population. We know, in most cases, the standard deviation of the population data is unknown. So, we will estimate it using the standard deviation of the sample data (sample standard deviation).
#
#                                 Hence Standard error = S/sqrt(n)
#
#         where S is the sd of sample data and n is the number of observations in the sample
#
#      Remember the standard deviation measures the variability or spread of the data around the mean.Standard error measures the spread of sample means around the population mean. Hence we can safely say "the standard error is computed as the standard deviation of the sample mean."
#
#     Note: The SE is always smaller than the SD.

# %% [markdown]
# #### How we come to the formula of standard error to S/sqrt(n)?
#     Theoritically, we can compute the standard error by taking repeated samples of same size from same population using the following steps:
#
#         1. Draw a new sample from the population.
#         2. Compute the sample mean of the drawn sample in Step 1
#         3. Repeat Steps 1 and 2 multiple times.
#         4. The standard error is obtained by computing the standard deviation of the previous steps sample means(samples statistics) from the population mean
#
#      Fortulately bcoz of Central Limit Theorem (CLT), we don’t need to consider the Sampling Distribution under repeated samples. Instead, the sampling distribution of the sample means can be estimated from just ONE random sample.
#
#     "The Central Limit Theorem states that the sample mean has an approximately normal distribution with a mean of μ and a standard deviation (or standard error) of σ/√n irrespective of its underlying distribution" Hence, with a reasonable sample size(40+), there is sufficient information within one set of samples.
#
#     Also, when we take repeated samples from a population, the sample statistics likely vary from one to other. The variation of samples depends on two factors:
#
#     Variation of the population: The bigger the population variation, the bigger the variation between samples.
#     Sample size: The bigger the sample size, the more likely they will resemble the population and each other. the smaller the variation between different sets of samples.
#
#     We rarely know the variation of the population, therefore we use sample standard deviation to estimate it. Then we divide it by the square root of the sample size to estimate the standard error of the sample mean.
#
#     Note: As we know from "Central Limit Theorem", we know the sampling distribution of statistics (e.g., sample means) follows a normal distribution. For Normal distribution we know, 95% of confidence lies in 2 standard deviations (here sd is representes by standard error). Hence the 95% confidence interval can be computed as "sample mean +/- 2 * standard error".
#
#     Here "2*standard error" is also called Z-SCORE. A z score is a standard score that tells you how many standard deviations away from the mean an individual value (x) lies:(here in this scenario x is standard error)
#     A positive z score means that your x value is greater than the mean.
#     A negative z score means that your x value is less than the mean.
#     A z score of zero means that your x value is equal to the mean.

# %% [markdown]
# #### Why do we need Standard Error (SE)?
#
#      It tells you how much the sample mean would vary if you were to repeat a study using new samples from within a single population. Standard error matters because it helps you estimate how well your sample data represents the whole population.
#
#      And, a high standard error shows that sample means are widely spread around the population mean—your sample may not closely represent your population. A low standard error shows that sample means are closely distributed around the population mean—your sample is representative of your population.
#
#     Also, Typically you might want "to construct confidence intervals" when we try to make statistical inferences(estimating population statistics like mean from sample statistics) to indicate the uncertainty around the estimate, and it is more "informative to assign a probability" to construct a confidence interval that contains the mean.
#
#     If the underlying data are normally distributed, then the sampling distribution is also normally distributed. Then we can say we are 68% confident that the population mean lies within 1 standard error or 95% will be within 2 standard errors, etc.
#
#     The greater the standard error – i.e., the wider the sampling distribution – the wider the confidence interval will be.
#
#     If the underlying data are NOT normally distributed, but the sample size is large enough, we can rely on Central Limit Theorem (CLT) to say the sampling distribution is approximately normally distributed, then we can make similar statements about confidence intervals.
#
#     We can decrease standard error by increasing sample size. Using a large, random sample is the best way to minimize sampling bias.
# ![confidence%20intervals.png](attachment:confidence%20intervals.png)
#
#     Here E is called "margin of error" => E = Z score * Standard error = Z * s/sqrt(n)

# %% [markdown]
# #### Difference between Standard Deviation and Standard Error?
#
#     The standard deviation describes variability within a single sample. Standard Deviation indicates how the sample data values are different from the mean in the sample distribution.
#
#     The standard error estimates the variability across multiple samples of a population. Standard Error indicates how the sample data statistics are different from the population statistic in the sampling distribution.

# %% [markdown]
# ### Confidence Interval
#     Confidence interval is the range of values, derived from sample statistics(mean and sd), that is likely(may or may not) to contain the value of an unknown population parameter(population mean and sd in case of normal distribution).
#
#     Confidence interval from standard error and mean the sample is:
#
# ![confidence_interval_equation.gif](attachment:confidence_interval_equation.gif)
#
#     Here Z is "Z score" at required confidence level. Z-score, otherwise known as the standard score, is the number of standard deviations by which a data point is above the mean.
#
#     Eg: Imagine that a brick maker is concerned whether the mass of bricks he manufactures is in line with specifications. He has measured the average mass of a sample of 100 bricks to be equal to 3 kg. He has also found the 95% confidence interval to be between 2.85 kg and 3.15 kg. It means that he can be 95% sure that the average mass of all the bricks he manufactures will lie between 2.85 kg and 3.15 kg. Of course, you don't always want to be exactly 95% sure. You might want to be 99% certain, or maybe it is enough for you that the confidence interval is correct in 90% of cases. This percentage is called the confidence level. We can interpret it as,for eg, if you repeatedly draw the 100 random samples and estimated the 95% confidence intervals 100 times for the true population mean, then the true population mean will be contained in about 95% of these confidence intervals. The remaining 5% of intervals will not contain the true population mean.
#
#     Also while constructing confidence interval at 95% confidence, then we can say that  we are 95% confident/sure that the true population statistic may lie in 95% confidence interval. Confidence interval indicates how confident we are about the conclusion, not the probability that the conclusion is correct.

# %% [markdown]
# ### Hypothesis Testing:
#     The purpose of Hypothesis Testing is to "evaluate the strength of evidence from the sample data for making the conclusions about the true population."
#     (Refer to Notebook 13 - tells about critical value approach and p-value approach of hypothesis testing)
#
#     In a hypothesis test, we evaluate two mutually exclusive statements about the population. They are
#
#             Null Hypothesis (H0): H0 always uses =.
#             Alternative Hypothesis (Ha): Ha can use > or < or ≠.
#
#                Eg: A null hypothesis could be "The average household income in Los Angeles is (=) 65,000". An alternative hypothesis could be "The average household income in Los Angeles is above (>) 65,000”, or "The average household income in Los Angeles is below (<)65,000", or "The average household income in Los Angeles is NOT(≠) 65,000".
#
#             The alternative Hypothesis using > or < indicates a "one-tailed test" because it only allows the alternative effect in one direction. The alternative Hypothesis using ≠ indicates a "two-tailed test" because it allows the alternative effect in two directions.
#
#             A hypothesis test is NOT designed to prove the null or alternative hypothesis. Instead, it evaluates the strength of evidence AGAINST the null hypothesis using sample data.
#
#             If we just want to find evidence against the null hypothesis, can we just compare the point estimate (e.g., sample mean) against the claim in the null hypothesis? If they turn out to be different (which will very likely happen), then does it mean we successfully falsify the null hypothesis? The answer is obviously NO.
#
#     We can only observe the sample data rather than the whole population. There is almost always a difference (aka Sampling Error) between the sample data and the population. Therefore, there is a likelihood that the sample mean is different from the claimed number in the null hypothesis due to the sampling error, even if the claimed number in the null hypothesis is the true population parameter. The hypothesis test is a tool to assess the "likelihood of this possibility".

# %% [markdown]
# #### How to do the hypothesis testing then?
#
#     Fortunately, we can create a probability distribution of the sample statistic (e.g., the sample mean) without repeated independent sampling using one of the two popular distributions
#
#     "Z-distribution": When the sample size is greater than 30 and the population standard deviation is known, the Z-distribution is recommended.(From Z distribution, Z score/statistic is determined).Note that Z distribution is nothing but standard normal distribution
#
#     "T-distribution": When the sample size is less than 30 or the population standard deviation is known, the T-distribution is recommended.(From Student's T/T distribution, the t-statistic/score is determined).The t-statistic is calculated as (x̄ - μ) / (s / √n) , where n denotes the sample size.Here x̄ is the observed value and μ is the expected value.We are basically finding out how different the observed value is from the expected value.
#
#     Note: We can also "Chi square distribution", which uses Chi square statistic to perform the hypothesis testing.We use a Chi-Square Test when the data to be analysed is from a random sample, and when the variable/s in the question is a categorical variable/s, then Chi-Square proves the most appropriate test for the same.
#
#     Usually, we don't have the population standard deviation, so we use the t-test.Population standard deviation is usually unknown and T-distribution is very similar to the normal distribution when the sample size is greater than 30, therefore, we would mostly apply T-distribution for a hypothesis test.Hence the rule is, when you know the population standard deviation you should use the z-test, when you estimate the sample standard deviation(unknown population sd) you should use the t-test.
#
#     Explanation using an example:
#     ----------------------------
#     It is claimed that the average household income in Los Angeles is 65,000. We randomly collect 10 samples from the population. It turns out that the sample mean is 70,000 with a sample standard deviation of 8,000(this is nothing but observed evidence). Assume normal distribution. Use a significance level of 0.05 to test the following hypothesis:
#             Let's use µ to denote the population mean.
#                     H0: µ = 65,000
#                     Ha: µ > 65,000
#
#             Let's compute the P-value which indicates the probability that the sample mean would be as extreme or more extreme than the observed one (e.g., the sample mean 70000) assuming the null hypothesis is correct." The observed significance or p-value of a test is a measure of how inconsistent the sample result is with H0 and in favor of Ha
#
#             In other words, if the population mean is truly 65,000, then the observed sample mean of 70,000 would be considered to be extreme because it is not close to 65,000 where as more extreme simply implies more extreme cases in the same direction as the alternative hypothesis.
#
#            Note: It is NOT correct to say P-value is the probability that the null hypothesis is correct because the population parameter stated in the null hypothesis is a fixed number, the probability that the null hypothesis is correct is either 0% or 100%.
#            Therefore, the P-value is computed as the probability that the sample mean is greater than 70,000, P(x̄ > 70,000).
#
#            Then we can rewrite the P-value by transforming x̄ into the test statistic t.
#
#                     P(x̄ > 70,000) = P(t = (x̄ —µ) / (s/√n) > (70000–65000)/(8000/√10)) = P(t > 1.976)
#
#            From the t-distribution table with 9 (n-1 = 10 -1) degrees of freedom, we can compute that P(t > 1.976) = 0.03979.
#
#            "The P-value of 0.03979 is smaller than the significance level of 0.05, therefore, we have enough evidence to reject the null hypothesis that the population mean is 65,000."

# %% [markdown]
# #### What is the Significance Level (α)?
#
#     The significant level is often denoted alpha or α. It indicates the threshold for statistical significance.
#
#     In other words, The significant level is the probability that we're willing to accept extreme events against the null hypothesis given that the null hypothesis is correct.
#
#     For example, a significance level of 0.05 means we would expect a 5% probability to see evidence against the null hypothesis even if the null hypothesis is correct.
#
#     1%, 5%, and 10% are all common thresholds of significant level. But they’re NOT exhaustive. We can choose any reasonable threshold of significant level based on how tolerant we’re willing to accept the false positive for a particular event given the null hypothesis is correct.
#
#     After we compute the P-value based on t or z statistic, how do we know if a P-value is small or big? Do we consider p-value = 0.02 small or p-value = 0.09 too big? This is where the Significance Level comes into play.
#
#     We would need to use the Significance Level as the benchmark to determine whether a p-value is small or big.

# %% [markdown]
# ### P-value
#
#       The p-value is the probability of obtaining test results at least as extreme as the result actually observed, under the assumption that the null hypothesis is correct. A very small p-value means that such an extreme observed outcome would be very unlikely under the null hypothesis.
#
#       "The observed significance or p-value of a test is a measure of how inconsistent the sample result is with H0 and in favor of Ha"
#
#        The p-value is used in the context of null hypothesis testing in order to quantify the statistical significance of a result, the result being the observed value of the chosen statistic T. The lower the p-value is, the lower the probability of getting that result if the null hypothesis were true. "A result is said to be statistically significant if it allows us to reject the null hypothesis". All other things being equal, smaller p-values are taken as stronger evidence against the null hypothesis. Loosely speaking, rejection of the null hypothesis implies that there is sufficient evidence against it.
#
#         As a particular example, if a null hypothesis states that a certain summary statistic T follows the standard normal distribution N(0,1), then the rejection of this null hypothesis could mean that (i) the mean of T is not 0, or (ii) the variance of T is not 1, or (iii) T is not normally distributed.
#
#         If the p-value is less than α(significance level), it mean that the observed data is sufficiently inconsistent with the null hypothesis for the null hypothesis to be rejected. However, that does not prove that the null hypothesis is false. "The p-value does not, in itself, establish probabilities of hypotheses. Rather, it is a tool for deciding whether to reject the null hypothesis."
#
#     How to interpret the result of the P-Value?
#     ----------------------------------------------
#
#     If a p-value is less than the Significance Level, then we can conclude the p-value is small. In other words, the probability that observing extreme events against the null hypothesis given that the null hypothesis is correct is very low. That means the evidence against the null hypothesis we found from the sample data would "rarely occur by chance". Therefore, We have enough evidence to reject the null hypothesis. It doesn't mean we've proved the alternative hypothesis is correct. It only means we accept the alternative hypothesis or we’re more confident that the alternative hypothesis is correct.
#
#     If a p-value is greater than the Significance Level, then we can conclude the p-value is big. In other words, the probability that observing extreme events against the null hypothesis given that the null hypothesis is correct is very high. That means the evidence against the null hypothesis we found from the sample data is "very likely occur by chance". Therefore, We DON’T have enough evidence to reject the null hypothesis. It doesn’t mean we’ve proved the null hypothesis is correct nor do we accept the null hypothesis.
